# %% [markdown]
# <a href="https://colab.research.google.com/github/eibarracuda/dadospesquisaTCC-DC/blob/main/Gr%C3%A1ficos%20e%20mapas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Geração de gráficos TCC
#
# - Grafico de canal por tema

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Definindo uma lista de cores personalizada
cores = ['#FF5733', '#33FF7E', '#337EFF', '#FF33F4', '#FF5733', '#33FF7E', '#337EFF', '#FF33F4', '#FF5733', '#33FF7E']

# Lê o arquivo CSV com a coluna de interesse
df = pd.read_csv('/content/mais1teste.csv', encoding='UTF-8')

# Cria uma série com a contagem de incidência das palavras
s = df['temacanal'].value_counts()

# Cria o gráfico de pizza com as 10 palavras mais frequentes
fig, ax = plt.subplots(figsize=(8, 8))
s.head(10).plot(kind='pie', ax=ax, autopct='%1.1f%%', colors=cores)

# Configura o título e o rótulo do gráfico
ax.set_title('Canais por tema')
ax.set_ylabel('')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Definindo uma lista de cores personalizada
cores = ['#FF5733', '#33FF7E', '#337EFF', '#FF33F4', '#FF5733', '#33FF7E', '#337EFF', '#FF33F4', '#FF5733', '#33FF7E']

# Lê o arquivo CSV com a coluna de interesse
df = pd.read_csv('/content/mais1teste.csv', encoding='UTF-8')

# Cria uma série com a contagem de incidência das palavras
s = df['temacanal'].value_counts()

# Cria o gráfico de pizza com as 10 palavras mais frequentes
fig, ax = plt.subplots(figsize=(8, 8))
s.head(10).plot(kind='pie', ax=ax, autopct='%1.0f', colors=cores)

# Configura o título e o rótulo do gráfico
ax.set_title('Canais por tema')
ax.set_ylabel('')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Definindo uma lista de cores personalizada
cores = ['#FF5733', '#33FF7E', '#337EFF', '#FF33F4', '#FF5733', '#33FF7E', '#337EFF', '#FF33F4', '#FF5733', '#33FF7E']

# Lê o arquivo CSV com a coluna de interesse
df = pd.read_csv('/content/mais1teste.csv', encoding='UTF-8')

# Cria uma série com a contagem de incidência das palavras
s = df['tipo'].value_counts()

# Cria o gráfico de pizza com as 10 palavras mais frequentes
fig, ax = plt.subplots(figsize=(8, 8))
s.head(10).plot(kind='pie', ax=ax, autopct='%1.0f', colors=cores)

# Configura o título e o rótulo do gráfico
ax.set_title('Canais por tema')
ax.set_ylabel('')

plt.show()

# %%
import pandas as pd

# ler o arquivo CSV
df = pd.read_csv('/content/mais1teste.csv')

# consultar os valores únicos da coluna "tipo"
tipos_unicos = df['tipo'].unique()

# imprimir os valores únicos
print(tipos_unicos)
# Out:
# ['#canaldc' '#canalentretenimento' '#canaljornalismo'
#  '#canalinstitucional/publico' '#importante #canalinstitucional/publico'
#  '#canalconrest' '#canalartesanato']

# %%
print(df[df['tipo'] == '#canalinstitucional/privado']
      )
# Out:
# Empty DataFrame
# Columns: [Total-videos, File, Created, Modified, Total-views, Total-likes, Total-comments, Total-video-length, Average-video-length, Videos-with-geolocation, Videos-with-recordingDate, Videos-with-tags, Videos-with-localizations, Videos-with-content-rating, Videos-with-region-restriction, Videos-with-comments-disabled, Videos-with-likes-disabled, Videos-with-views-disabled, Videos-considered-livestreams, Videos-creativeCommon, Videos-with-madeForKidstrue, criado-em, tema, titulo, contexto, created, updated, location, tagscanal, temacanal, monetized, tipo, vinteresse]
# Index: []
#
# [0 rows x 33 columns]

# %%
df_filtrado = df[df['tipo'] == '#canalinstitucional/privado']
print(df_filtrado)
# Out:
# Empty DataFrame
# Columns: [Total-videos, File, Created, Modified, Total-views, Total-likes, Total-comments, Total-video-length, Average-video-length, Videos-with-geolocation, Videos-with-recordingDate, Videos-with-tags, Videos-with-localizations, Videos-with-content-rating, Videos-with-region-restriction, Videos-with-comments-disabled, Videos-with-likes-disabled, Videos-with-views-disabled, Videos-considered-livestreams, Videos-creativeCommon, Videos-with-madeForKidstrue, criado-em, tema, titulo, contexto, created, updated, location, tagscanal, temacanal, monetized, tipo, vinteresse]
# Index: []
#
# [0 rows x 33 columns]

# %%
df['titulo'].count()
# Out:
# 30

# %% [markdown]
# ***
#
# # Importando dados

# %%
import pandas as pd

df1 = pd.read_csv('/content/1.csv')
df2 = pd.read_csv('/content/2.csv')
df3 = pd.read_csv('/content/3.csv')

df = pd.concat([df1, df2, df3], ignore_index=True)

# Define um nome mais amigável para o dataframe
df_canais = df

# Imprime as primeiras linhas do dataframe com o novo nome
print(df_canais.head())
# Out:
#    Total-videos                                               File  \
# 0           125  03. Acervos/Acervo Conservação-Restauração/; 2...
# 1            16  03. Acervos/Acervo Conservação-Restauração/; 2...
# 2             3  03. Acervos/Acervo Conservação-Restauração/; 2...
# 3         19979  03. Acervos/Acervo Conservação-Restauração/; 2...
# 4         19931  03. Acervos/Acervo Conservação-Restauração/; 2...
#
#                          Created                       Modified  Total-views  \
# 0  2023-03-08T09:34:52.014-03:00  2023-03-13T08:07:13.806-03:00       106934
# 1  2023-03-02T18:57:16.347-03:00  2023-03-13T08:08:19.082-03:00      1762349
# 2  2023-03-10T16:45:20.248-03:00  2023-03-13T08:08:08.747-03:00           88
# 3  2023-03-07T15:19:33.319-03:00  2023-03-13T08:07:23.958-03:00     26189336
# 4  2023-03-06T15:50:33.218-03:00  2023-03-13T08:08:03.435-03:00      4212737
#
#    Total-likes  Total-comments  \
# 0       6148.0           471.0
# 1       9199.0           731.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv('/content/1.csv')
df2 = pd.read_csv('/content/2.csv')
df3 = pd.read_csv('/content/3.csv')

df = pd.concat([df1, df2, df3], ignore_index=True)




# Definindo uma lista de cores personalizada
cores = ['#FF5733', '#33FF7E', '#337EFF', '#FF33F4', '#FF5733', '#33FF7E', '#337EFF', '#FF33F4', '#FF5733', '#33FF7E']



# Cria uma série com a contagem de incidência das palavras
s = df['temacanal'].value_counts()

# Cria o gráfico de pizza com as 10 palavras mais frequentes
fig, ax = plt.subplots(figsize=(8, 8))
s.head(10).plot(kind='pie', ax=ax, autopct='%1.0f', colors=cores)

# Configura o título e o rótulo do gráfico
ax.set_title('Canais por tema')
ax.set_ylabel('')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv('/content/1.csv')
df2 = pd.read_csv('/content/2.csv')
df3 = pd.read_csv('/content/3.csv')
df4 = pd.read_csv('/content/4.csv')

df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# Definindo uma lista de cores personalizada
cores = ['#FF5733', '#33FF7E', '#337EFF', '#FF33F4', '#FF5733', '#33FF7E', '#337EFF', '#FF33F4', '#FF5733', '#33FF7E']

# Cria uma série com a contagem de incidência das palavras
s = df['tipo'].value_counts()

# Cria o gráfico de pizza com as 10 palavras mais frequentes
fig, ax = plt.subplots(figsize=(8, 8))
s.plot(kind='pie', ax=ax, autopct='%1.0f', colors=cores)

# Configura o título e o rótulo do gráfico
ax.set_title('Canais por tema')
ax.set_ylabel('')

plt.show()

# %%
print(df.temacanal)
# Out:
# 0         Institucional,Museu
# 1                    Religião
# 2                  Jornalismo
# 3                  Jornalismo
# 4                  Jornalismo
# 5                  Jornalismo
# 6               Institucional
# 7               Institucional
# 8               Institucional
# 9               Institucional
# 10              Institucional
# 11              Institucional
# 12              Institucional
# 13              Institucional
# 14              Institucional
# 15              Institucional
# 16                   História
# 17                   História
# 18             Entretenimento
# 19             Entretenimento
# 20      Divulgação Cientifica
# 21    Conservação-Restauração
# 22    Conservação-Restauração
# 23    Conservação-Restauração
# 24    Conservação-Restauração
# 25    Conservação-Restauração
# 26    Conservação-Restauração
# 27                 Artesanato
# 28                       Arte
# 29                       Arte
# 30              Institucional
# ...

# %%
df1 = pd.read_csv('/content/1.csv')
df2 = pd.read_csv('/content/2.csv')
df3 = pd.read_csv('/content/3.csv')
df4 = pd.read_csv('/content/4.csv')

df = pd.concat([df1, df2, df3, df4], ignore_index=True)
df = df.replace('Institucional,Museu', 'Institucional')

counts = df.groupby('tipo').size()

# Cria o gráfico de barras
fig, ax = plt.subplots(figsize=(8, 6))
counts.plot(kind='bar', ax=ax, color='purple')

# Configura o título e os rótulos dos eixos
ax.set_title('Incidência por tipo')
ax.set_xlabel('Tipo')
ax.set_ylabel('Incidência')

plt.show()

# %%
df1 = pd.read_csv('/content/1.csv')
df2 = pd.read_csv('/content/2.csv')
df3 = pd.read_csv('/content/3.csv')
df4 = pd.read_csv('/content/4.csv')

df = pd.concat([df1, df2, df3, df4], ignore_index=True)
df = df.replace('#importante #canalinstitucional/publico', '#canalinstitucional/publico')
df = df.replace('Institucional,Museu', 'Institucional')

counts = df.groupby('tipo').size()

# Define um nome mais amigável para a série
s = counts

# Cria o gráfico de pizza
fig, ax = plt.subplots(figsize=(8, 8))
s.plot(kind='pie', ax=ax, autopct='%1.0f', pctdistance=0.85)

# Configura o título e o rótulo do gráfico
ax.set_title('Incidência por tipo')
ax.set_ylabel('')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv('/content/1.csv')
df2 = pd.read_csv('/content/2.csv')
df3 = pd.read_csv('/content/3.csv')
df4 = pd.read_csv('/content/4.csv')

df = pd.concat([df1, df2, df3, df4], ignore_index=True)
df = df.replace('#importante #canalinstitucional/publico', '#canalinstitucional/publico')
df = df.replace('Institucional,Museu', 'Institucional')

# Definindo uma lista de cores personalizada
cores = ['#9e0142', '#d53e4f', '#f46d43', '#fdae61', '#fee08b', '#e6f598', '#abdda4', '#66c2a5', '#3288bd', '#5e4fa2']

# Cria uma série com a contagem de incidência das palavras
s = df['temacanal'].value_counts()

# Define uma função para exibir a contagem em vez da porcentagem
def func(pct, allvals):
    absolute = int(round(pct/100.*sum(allvals)))
    return "{:d}".format(absolute)

# Cria o gráfico de pizza com as 10 palavras mais frequentes
fig, ax = plt.subplots(figsize=(8, 8))
s.plot(kind='pie', ax=ax, autopct=lambda pct: func(pct, s.values), colors=cores)

# Configura o título e o rótulo do gráfico
ax.set_title('Canais por tema')
ax.set_ylabel('')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv('/content/1.csv')
df2 = pd.read_csv('/content/2.csv')
df3 = pd.read_csv('/content/3.csv')
df4 = pd.read_csv('/content/4.csv')

df = pd.concat([df1, df2, df3, df4], ignore_index=True)
df = df.replace('#importante #canalinstitucional/publico', '#canalinstitucional/publico')
df = df.replace('Institucional,Museu', 'Institucional')

# Agrupa os dados pela coluna "temacanal" e calcula a soma dos valores da coluna "vinteresse"
s = df.groupby('temacanal')['vinteresse'].sum()

# Define uma função para exibir a contagem em vez da porcentagem
def func(pct, allvals):
    absolute = int(round(pct/100.*sum(allvals)))
    return "{:d}".format(absolute)

# Define uma lista de cores personalizada
cores = ['#9e0142', '#d53e4f', '#f46d43', '#fdae61', '#fee08b', '#e6f598', '#abdda4', '#66c2a5', '#3288bd', '#5e4fa2']

# Cria o gráfico de pizza com as somas dos valores da coluna "vinteresse" agrupados pela coluna "temacanal"
fig, ax = plt.subplots(figsize=(8, 8))
s.plot(kind='pie', ax=ax, autopct=lambda pct: func(pct, s.values), colors=cores)

# Configura o título e o rótulo do gráfico
ax.set_title('Soma dos valores de interesse por tema')
ax.set_ylabel('')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv('/content/1.csv')
df2 = pd.read_csv('/content/2.csv')
df3 = pd.read_csv('/content/3.csv')
df4 = pd.read_csv('/content/4.csv')

df = pd.concat([df1, df2, df3, df4], ignore_index=True)
df = df.replace('#importante #canalinstitucional/publico', '#canalinstitucional/publico')
df = df.replace('Institucional,Museu', 'Institucional')

# Define um dicionário de cores para cada valor único da coluna "temacanal"
colors_dict = {'Conservação-Restauração': '#d53e4f',
               'Arte': '#e6f598',
               'Religião': '#abdda4',
               'Jornalismo': '#f46d43',
               'Institucional': '#9e0142',
               'História': '#fdae61',
               'Entretenimento': '#fee08b',
               'Divulgação Cientifica': '#22c994',
               'Artesanato': '#3288bd',
               }

# Cria uma série com a soma dos valores da coluna "vinteresse" agrupados pela coluna "temacanal"
s = df.groupby('temacanal')['vinteresse'].sum()

# Define uma função para exibir a contagem em vez da porcentagem
def func(pct, allvals):
    absolute = int(round(pct/100.*sum(allvals)))
    return "{:d}".format(absolute)

# Cria o gráfico de pizza com as 10 palavras mais frequentes
fig, ax = plt.subplots(figsize=(8, 8))
s.plot(kind='pie', ax=ax, autopct=lambda pct: func(pct, s.values), colors=[colors_dict[x] for x in s.index])

# Configura o título e o rótulo do gráfico
ax.set_title('Videos por categoria')
ax.set_ylabel('')

plt.show()

# %% [markdown]
# # Outras consulta
#
# Estabelecer o dataframe:

# %%
df1 = pd.read_csv('/content/1.csv')
df2 = pd.read_csv('/content/2.csv')
df3 = pd.read_csv('/content/3.csv')
df4 = pd.read_csv('/content/4.csv')

df = pd.concat([df1, df2, df3, df4], ignore_index=True)
df = df.replace('#importante #canalinstitucional/publico', '#canalinstitucional/publico')
df = df.replace('Institucional,Museu', 'Institucional')

# %% [markdown]
# Quantos videos nos canais de conservação restauração

# %%
df[df['temacanal'] == 'Conservação-Restauração']['vinteresse'].sum()
# Out:
# 60

# %%
print(df.vinteresse.sum())
# Out:
# 162

# %%
print(df.tagscanal)
# Out:
# 0     Museu de Arte Sacra,arte sacra,MAS,museu,museu...
# 1     de,Holy Mary,Catholic,Christ,Jesus,Christianit...
# 2                         ciclista,bicicleta,reportagem
# 3     TV Brasil,EBC,TV Pública,eleições 2022,previsã...
# 4     TV Correio,Paraíba,João Pessoa,Afiliada Record...
# 5     Gospel,gospel,Música gospel,Jornal do Maranhão...
# 6     stj,direito,tribunal,superior,justiça,lei,cida...
# 7     FAPESP,pesquisa,fapesp,USP,coronavírus,Fundaçã...
# 8     Fundaj,Fundação Joaquim Nabuco,fundaj,Muhne,Mu...
# 9     câmara dos deputados,deputados federais,congre...
# 10    Univesp,Univesp TV,educação,graduação,univesp,...
# 11    Ministério,Público,Santa,Catarina,Promotor,de,...
# 12    fruto de arte,aquarela,caligrafia,material art...
# 13    Stellantis,Somos Stellantis,Fiat,Jeep,Peugeot,...
# 14    Tubarão,Unisul TV,Educação,Unisul,Thiago Perei...
# 15    tv unimep,unimep,piracicaba,UNIMEP,caroll bera...
# 16    história,Bridgerton,Netflix,curiosidades,rainh...
# ...

# %%
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

nltk.download('stopwords')
nltk.download('punkt')

df1 = pd.read_csv('/content/1.csv')
df2 = pd.read_csv('/content/2.csv')
df3 = pd.read_csv('/content/3.csv')
df4 = pd.read_csv('/content/4.csv')

df = pd.concat([df1, df2, df3, df4], ignore_index=True)
df = df.replace('#importante #canalinstitucional/publico', '#canalinstitucional/publico')
df = df.replace('Institucional,Museu', 'Institucional')

# Definir a lista de stopwords em português
stop_words = set(stopwords.words('portuguese'))

# Criar um dicionário vazio para armazenar as frequências de palavras
word_freq = {}

# Loop pelas linhas do dataframe
for tags in df['tagscanal']:
    # Converter cada campo em uma string usando str()
    text = str(tags)
    # Tokenizar o texto em palavras
    words = nltk.word_tokenize(text.lower())
    # Remover as stopwords do texto
    filtered_words = [word for word in words if not word.lower() in stop_words]
    # Contar a frequência de cada palavra e adicionar ao dicionário
    for word in filtered_words:
        if word in word_freq:
            word_freq[word] += 1
        else:
            word_freq[word] = 1

# Carregar a imagem da máscara
mask = np.array(Image.open("/content/mask3.png"))

# Gerar as cores para a nuvem de palavras com base na máscara
image_colors = ImageColorGenerator(mask)

# Criar o objeto WordCloud com a máscara e as frequências de palavras
wordcloud = WordCloud(width=800, height=800,
                      background_color='white',
                      mask=mask,
                      min_font_size=10,
                      max_font_size=100).generate_from_frequencies(word_freq)

# Aplicar as cores da máscara na nuvem de palavras
wordcloud = wordcloud.recolor(color_func=image_colors)

# Mostrar a imagem gerada
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.tight_layout(pad=0)

# Salvar a imagem gerada
plt.savefig('mapa_de_palavras.png')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import pandas as pd

nltk.download('stopwords')
nltk.download('punkt')

df1 = pd.read_csv('/content/1.csv')
df2 = pd.read_csv('/content/2.csv')
df3 = pd.read_csv('/content/3.csv')
df4 = pd.read_csv('/content/4.csv')

df = pd.concat([df1, df2, df3, df4], ignore_index=True)
df = df.replace('#importante #canalinstitucional/publico', '#canalinstitucional/publico')
df = df.replace('Institucional,Museu', 'Institucional')

# Definir a lista de stopwords em português
stop_words = set(stopwords.words('portuguese'))

# Criar um dicionário vazio para armazenar as frequências de palavras
word_freq = {}

# Loop pelas linhas do dataframe
for tags in df['tagscanal']:
    # Converter cada campo em uma string usando str()
    text = str(tags)
    # Tokenizar o texto em palavras
    words = nltk.word_tokenize(text.lower())
    # Remover as stopwords do texto e contar a frequência de cada palavra
    for word in set(words):
        if not word.lower() in stop_words:
            if word in word_freq:
                word_freq[word] += 1
            else:
                word_freq[word] = 1

# Carregar a imagem da máscara
mask = np.array(Image.open("/content/mask3.png"))

# Gerar as cores para a nuvem de palavras com base na máscara
image_colors = ImageColorGenerator(mask)

# Criar o objeto WordCloud com a máscara e as frequências de palavras
wordcloud = WordCloud(width=800, height=800,
                      background_color='white',
                      mask=mask,
                      min_font_size=10,
                      max_font_size=100).generate_from_frequencies(word_freq)

# Aplicar as cores da máscara na nuvem de palavras
wordcloud = wordcloud.recolor(color_func=image_colors)

# Mostrar a imagem gerada
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.tight_layout(pad=0)

# Salvar a imagem gerada
plt.savefig('mapa_de_palavras.png')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
